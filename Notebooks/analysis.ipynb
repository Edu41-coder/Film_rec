# %%
# Importer les bibliothèques nécessaires
import pandas as pd

# Charger les données
movie_matrix = pd.read_csv("F:/Film_recom/Datasets/movies_ratings_merged.csv")

# Afficher les premières lignes du DataFrame pour comprendre sa structure
print("Aperçu des données :")
print(movie_matrix.head())

# Échantillonner 10 % des données aléatoirement
sample_size = int(0.01 * len(movie_matrix))  # Calculer 10 % de la taille des données
movie_matrix_sample = movie_matrix.sample(n=sample_size, random_state=42)  # Échantillonner

# Afficher les informations sur l'échantillon
print("\nInformations sur l'échantillon :")
print(movie_matrix_sample.info())

# Afficher les statistiques descriptives de l'échantillon
print("\nStatistiques descriptives :")
print(movie_matrix_sample.describe())

# Afficher les colonnes de l'échantillon
print("\nColonnes de l'échantillon :")
print(movie_matrix_sample.columns)

# Afficher les value counts de la colonne 'rating'
print("\nValue counts de la colonne 'rating' :")
print(movie_matrix_sample['rating'].value_counts())
# Out:
# Aperçu des données :
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating
# 0       3     4.0
# 1       6     5.0
# 2       8     4.0
# 3      10     4.0
# 4      11     4.5
#
# Informations sur l'échantillon :
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200002 entries, 17679788 to 4250478
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   movieId  200002 non-null  int64
#  1   title    200002 non-null  object
#  2   genres   200002 non-null  object
# ...
